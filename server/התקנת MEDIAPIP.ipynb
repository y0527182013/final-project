# %%
# %pip install -q mediapipe
print("Installed mediapipe")

# %%
# !wget -O face_landmarker_v2_with_blendshapes.task -q https://storage.googleapis.com/mediapipe-models/face_landmarker/face_landmarker/float16/1/face_landmarker.task

# %%
import os
import mediapipe as mp
import cv2
import numpy as np
import datetime
from mediapipe import solutions
from mediapipe.framework.formats import landmark_pb2
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
arrMatchingTraits = []
arrf=[f1,f2,f3,f4]
def draw_landmarks_on_image(rgb_image, detection_result):
    face_landmarks_list = detection_result.face_landmarks
    annotated_image = np.copy(rgb_image)
    
    for face_landmarks in face_landmarks_list:
        face_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
        face_landmarks_proto.landmark.extend([
            landmark_pb2.NormalizedLandmark(x=landmark.x, y=landmark.y, z=landmark.z) 
            for landmark in face_landmarks
        ])
        
        solutions.drawing_utils.draw_landmarks(
            image=annotated_image,
            landmark_list=face_landmarks_proto,
            connections=mp.solutions.face_mesh.FACEMESH_TESSELATION,
            landmark_drawing_spec=None,
            connection_drawing_spec=mp.solutions.drawing_styles
            .get_default_face_mesh_tesselation_style())
        
        solutions.drawing_utils.draw_landmarks(
            image=annotated_image,
            landmark_list=face_landmarks_proto,
            connections=mp.solutions.face_mesh.FACEMESH_CONTOURS,
            landmark_drawing_spec=None,
            connection_drawing_spec=mp.solutions.drawing_styles
            .get_default_face_mesh_contours_style())
        
        solutions.drawing_utils.draw_landmarks(
            image=annotated_image,
            landmark_list=face_landmarks_proto,
            connections=mp.solutions.face_mesh.FACEMESH_IRISES,
            landmark_drawing_spec=None,
            connection_drawing_spec=mp.solutions.drawing_styles
            .get_default_face_mesh_iris_connections_style())
        
    return annotated_image

# יצירת תיקייה לשמירת תמונות
save_dir = "saved_images"
os.makedirs(save_dir, exist_ok=True)

# פתיחת מצלמה
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Could not open camera.")
    exit()

print("Press 's' to save the image and exit, or 'q' to exit without saving.")
while True:
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame.")
        break

    cv2.imshow("Camera", frame)
    key = cv2.waitKey(1) & 0xFF
    if key == ord('s'):
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        image_path = os.path.join(save_dir, f"captured_image_{timestamp}.png")
        cv2.imwrite(image_path, frame)
        print(f"Image saved as '{image_path}'")
        break
    elif key == ord('q'):
        print("Exiting without saving.")
        break

# שחרור המצלמה וסגירת חלונות
cap.release()
cv2.destroyAllWindows()

# קריאת התמונה שנשמרה
image_format = mp.ImageFormat.SRGB
image = mp.Image(image_format, np.array(frame))

# יצירת מודל לזיהוי נקודות פנים
base_options = python.BaseOptions(model_asset_path=r'C:\face_landmarker_v2_with_blendshapes.task')
options = vision.FaceLandmarkerOptions(base_options=base_options,
                                       output_face_blendshapes=True,
                                       output_facial_transformation_matrixes=True,
                                       num_faces=1)
detector = vision.FaceLandmarker.create_from_options(options)

# זיהוי נקודות הפנים
detection_result = detector.detect(image)

# ציור הנקודות על התמונה
annotated_image = draw_landmarks_on_image(image.numpy_view(), detection_result)

# הצגת התמונה עם הנקודות
cv2.imshow("Annotated Image", cv2.cvtColor(annotated_image, cv2.COLOR_RGB2BGR))
cv2.waitKey(0)
cv2.destroyAllWindows()
for i in range(0,4):
    # להוסיף כאן בדיקה עם זה בתווך של הממוצעים
    arrMatchingTraits.append(arrf[i]())
print(arrMatchingTraits)
# Out:
# Press 's' to save the image and exit, or 'q' to exit without saving.
# Image saved as 'saved_images\captured_image_20250406_154919.png'
# Filename: 9.jpg
# y1 (landmark 454): 0.6355553865432739, x1 (landmark 234): 0.4157027304172516
# y2 (landmark 152): 0.927523136138916, x2 (landmark 10): 0.5837433338165283
# [0.41514030110118433, -0.9908345858261054, 0.03254950188665237, 4.326312218219235]

# %%
import os
import mediapipe as mp
import cv2
import numpy as np
import matplotlib.pyplot as plt  # ייבוא הספרייה החסרה
from mediapipe import solutions
from mediapipe.framework.formats import landmark_pb2
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

arr1=[]
arr2=[]
arr3=[]
arr4=[]
arr5=[]
arr6=[]
arr7=[]
arr8=[]
# פונקציה לציור נקודות על התמונה
def draw_landmarks_on_image(rgb_image, detection_result):
    face_landmarks_list = detection_result.face_landmarks
    annotated_image = np.copy(rgb_image)

    for face_landmarks in face_landmarks_list:
        face_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
        face_landmarks_proto.landmark.extend([
            landmark_pb2.NormalizedLandmark(x=landmark.x, y=landmark.y, z=landmark.z) for landmark in face_landmarks
        ])
        solutions.drawing_utils.draw_landmarks(
            image=annotated_image,
            landmark_list=face_landmarks_proto,
            connections=mp.solutions.face_mesh.FACEMESH_TESSELATION,
            landmark_drawing_spec=None,
            connection_drawing_spec=mp.solutions.drawing_styles.get_default_face_mesh_tesselation_style())
        solutions.drawing_utils.draw_landmarks(
            image=annotated_image,
            landmark_list=face_landmarks_proto,
            connections=mp.solutions.face_mesh.FACEMESH_CONTOURS,
            landmark_drawing_spec=None,
            connection_drawing_spec=mp.solutions.drawing_styles.get_default_face_mesh_contours_style())
        solutions.drawing_utils.draw_landmarks(
            image=annotated_image,
            landmark_list=face_landmarks_proto,
            connections=mp.solutions.face_mesh.FACEMESH_IRISES,
            landmark_drawing_spec=None,
            connection_drawing_spec=mp.solutions.drawing_styles.get_default_face_mesh_iris_connections_style())
    
    return annotated_image

# נתיב לתיקייה עם תמונות (יש לעדכן את הנתיב הרצוי)
input_folder = r"C:\Users\This User\Desktop\fase"
output_folder = r"C:\Users\This User\Desktop\fase2"
os.makedirs(output_folder, exist_ok=True)  # יצירת תיקיית פלט אם לא קיימת

# טעינת המודל של FaceLandmarker
base_options = python.BaseOptions(model_asset_path=r'C:\face_landmarker_v2_with_blendshapes.task')
options = vision.FaceLandmarkerOptions(
    base_options=base_options,
    output_face_blendshapes=True,
    output_facial_transformation_matrixes=True,
    num_faces=1
)
detector = vision.FaceLandmarker.create_from_options(options)

# מעבר על כל התמונות בתיקייה
for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):  # סינון קבצים שהם תמונות
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, f"annotated_{filename}")

        # קריאת התמונה
        frame = cv2.imread(input_path)
        if frame is None:
            print(f"Warning: Could not read {filename}, skipping.")
            continue

        # המרת צבעים ל-RGB לעיבוד עם MediaPipe
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image = mp.Image(image_format=mp.ImageFormat.SRGB, data=frame_rgb)

        # זיהוי נקודות פנים
        detection_result = detector.detect(image)

        if detection_result.face_landmarks:
            # ציור הנקודות ושמירת התוצאה
            annotated_image = draw_landmarks_on_image(image.numpy_view(), detection_result)
            cv2.imwrite(output_path, cv2.cvtColor(annotated_image, cv2.COLOR_RGB2BGR))

        # חישוב צורת האף
        #nose_shape = classify_nose_shape(detection_result.face_landmarks[0], filename)
        #arraf.append(nose_shape)
        # חישוב הקצוות הפנימיים של העיניים בשביל כושר שיפוט
        b1=f1()
        b2=f2()
        b3=f3()
        b4=f4()
        b5=f5()
        b6=f6()
        b7=f7()
        b8=f8()
        # חישוב המרחק בין קצוות העיניים
        if b1 is not None:
            arr1.append(b1)
        else:
            arr1.append("Face not detected")
        if b2 is not None:
            arr2.append(abs(b2))
        else:
            arr2.append("Face not detected")
        if b3 is not None:
            arr3.append(abs(b3))
        else:
            arr3.append("Face not detected")
        if b4 is not None:
            arr4.append(b4)
        else:
            arr4.append("Face not detected")
        if b5 is not None:
            arr5.append(b5)
        else:
            arr5.append("Face  detected")
        if b6 is not None:
            arr6.append(b6)
        else:
            arr6.append("Face  detected")
        if b7 is not None:
            arr7.append(b7)
        else:
            arr7.append("Face  detected")
        if b8 is not None:
            arr8.append(b8)
        else:
            arr8.append("Face  detected")
print(arr1)
avg1 = np.mean(arr1)
print(np.format_float_positional(avg1))
print(arr2)   
avg2 = np.mean(arr2)
print(np.format_float_positional(avg2))
print(arr3)
avg3=np.mean(arr3)
print(np.format_float_positional(avg3))
avg4 = np.mean(arr4)
print(arr4)
print(np.format_float_positional(avg4))
avg5=np.mean(arr5)
print(arr5)
print(np.format_float_positional(avg5))
avg6=np.mean(arr6)
print(arr6)
print(np.format_float_positional(avg6))
avg7=np.mean(arr7)
print(arr7)
print(np.format_float_positional(avg7))
avg8=np.mean(arr8)
print(arr8)
print(np.format_float_positional(avg8))
print("Processing complete. All images saved in:", output_folder)
# Out:
# [1.413997008446002, 0.47727130562507303, 1.4200633035983958, 0.8165620027599741, 0.8563851271740603, 2.2410848689990948, 0.61495872507989, 0.6293617175064393, 0.5929495023303311, 0.5446968246737233]
# 0.9607330386192983
# [0.7642666057415008, 1.3833643631961774, 0.8202478246940513, 4.556885499523019, 4.817431630583797, 0.9131831178496814, 0.45811723925816883, 0.10290166762799914, 0.23346034537670893, 0.2544384671747451]
# 1.4304296761025848
# [0.0269908659392198, 4.997655023733429, 0.35364227765275436, 1.1782512906825018, 0.43939465572344416, 4.667301764405529, 0.1761616142514041, 2.936416157642921, 2.9816609618184917, 0.2194822141114621]
# 1.7976956825961157
# [0.3593724559201231, 0.36962184921677693, 0.33310010495277126, 0.8494965495087342, 0.8614558681742484, 0.24181198458387335, 0.3798900228995159, 0.2461369153851544, 0.27242999345985613, 0.2218436833821449]
# 0.4135159427483199
# ...
