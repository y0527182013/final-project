# %%
import os
import cv2
import mediapipe as mp
from facial_features_functions import f1, f2, f3, f4, f5, f6, f7, f8,f9
arrMatchingTraits = []
arrf =[f9]
arr1=[]
arr2=[]
arr3=[]
arr4=[]
arr5=[]
arr6=[]
arr7=[]
arr8=[]
arrFase=["1","11","2","22","3","33","4","4","5","55","6","66","7","77","8","88"]
# for i in range(0,16):
  # נתיב לתיקייה עם תמונות (יש לעדכן את הנתיב הרצוי)
input_folder = r"C:\Users\This User\Desktop\fase"
output_folder = r"C:\Users\This User\Desktop\fase2"
# os.makedirs(output_folder, exist_ok=True)  # יצירת תיקיית פלט אם לא קיימת
# מעבר על כל התמונות בתיקייה
for filename in os.listdir(input_folder):
   arr=[]
   if filename.lower().endswith(('.png', '.jpg', '.jpeg')):  # סינון קבצים שהם תמונות
      input_path = os.path.join(input_folder, filename)
      output_path = os.path.join(output_folder, f"annotated_{filename}")
      # קריאת התמונה
      frame = cv2.imread(input_path)
      if frame is None:
          print(f"Warning: Could not read {filename}, skipping.")
          continue
      # המרת צבעים ל-RGB לעיבוד עם MediaPipe
      frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
      image = mp.Image(image_format=mp.ImageFormat.SRGB, data=frame_rgb)
      # זיהוי נקודות פנים
      detection_result = detector.detect(image)
      if detection_result.face_landmarks:
          # ציור הנקודות ושמירת התוצאה
          annotated_image = draw_landmarks_on_image(image.numpy_view(), detection_result)
          cv2.imwrite(output_path, cv2.cvtColor(annotated_image, cv2.COLOR_RGB2BGR))
   b9=f9(detection_result) 
   print(b9)

# %% [markdown]
# קוד שצמצמתי ללולאה אחת ולכאורה אני לא צריכה אותו

# %%
# הגדרת מודול Mediapipe
def draw_landmarks_on_image(rgb_image, detection_result):
    face_landmarks_list = detection_result.face_landmarks
    annotated_image = np.copy(rgb_image)
    for face_landmarks in face_landmarks_list:
        face_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
        face_landmarks_proto.landmark.extend([
            landmark_pb2.NormalizedLandmark(x=landmark.x, y=landmark.y, z=landmark.z) 
            for landmark in face_landmarks
        ])
        solutions.drawing_utils.draw_landmarks(
            image=annotated_image,
            landmark_list=face_landmarks_proto,
            connections=mp.solutions.face_mesh.FACEMESH_TESSELATION,
            landmark_drawing_spec=None,
            connection_drawing_spec=mp.solutions.drawing_styles
            .get_default_face_mesh_tesselation_style())   
        solutions.drawing_utils.draw_landmarks(
            image=annotated_image,
            landmark_list=face_landmarks_proto,
            connections=mp.solutions.face_mesh.FACEMESH_CONTOURS,
            landmark_drawing_spec=None,
            connection_drawing_spec=mp.solutions.drawing_styles
            .get_default_face_mesh_contours_style())
        solutions.drawing_utils.draw_landmarks(
            image=annotated_image,
            landmark_list=face_landmarks_proto,
            connections=mp.solutions.face_mesh.FACEMESH_IRISES,
            landmark_drawing_spec=None,
            connection_drawing_spec=mp.solutions.drawing_styles
            .get_default_face_mesh_iris_connections_style()) 
    return annotated_image

# %%
# חישוב ממוצעים של תכונות פנים
import os
import cv2
import mediapipe as mp
from facial_features_functions import f1, f2, f3, f4, f5, f6, f7, f8,f9
arrMatchingTraits = []
arrf =[f9]
arr1=[]
arr2=[]
arr3=[]
arr4=[]
arr5=[]
arr6=[]
arr7=[]
arr8=[]
arrFase=["1","11","2","22","3","33","4","4","5","55","6","66","7","77","8","88"]
# for i in range(0,16):
  # נתיב לתיקייה עם תמונות (יש לעדכן את הנתיב הרצוי)
input_folder = r"C:\Users\This User\Desktop\fase"
output_folder = r"C:\Users\This User\Desktop\fase2"
# os.makedirs(output_folder, exist_ok=True)  # יצירת תיקיית פלט אם לא קיימת
# מעבר על כל התמונות בתיקייה
for filename in os.listdir(input_folder):
   arr=[]
   if filename.lower().endswith(('.png', '.jpg', '.jpeg')):  # סינון קבצים שהם תמונות
      input_path = os.path.join(input_folder, filename)
      output_path = os.path.join(output_folder, f"annotated_{filename}")
      # קריאת התמונה
      frame = cv2.imread(input_path)
      if frame is None:
          print(f"Warning: Could not read {filename}, skipping.")
          continue
      # המרת צבעים ל-RGB לעיבוד עם MediaPipe
      frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
      image = mp.Image(image_format=mp.ImageFormat.SRGB, data=frame_rgb)
      # זיהוי נקודות פנים
      detection_result = detector.detect(image)
      if detection_result.face_landmarks:
          # ציור הנקודות ושמירת התוצאה
          annotated_image = draw_landmarks_on_image(image.numpy_view(), detection_result)
          cv2.imwrite(output_path, cv2.cvtColor(annotated_image, cv2.COLOR_RGB2BGR))

   b9=f9(detection_result) 
   print(b9)
       #   b=arrf[int(arrFase[i])%10-1](detection_result)
    #   if b is not None:
    #       arr.append(b)
    #   else:
    #       arr.append("Face not detected")
# avg= np.mean(arr)
#    b1=f1(detection_result)
#    b2=f2(detection_result)
#    b3=f3(detection_result)
#    b4=f4(detection_result)
#    b5=f5(detection_result)
#    b6=f6(detection_result)
#    b7=f7(detection_result)
#    b8=f8(detection_result)
#    if b1 is not None:
#        arr1.append(b1)
#    else:
#        arr1.append("Face not detected")
#    if b2 is not None:
#        arr2.append(abs(b2))
#    else:
#        arr2.append("Face not detected")
#    if b3 is not None:
#        arr3.append(abs(b3))
#    else:
#        arr3.append("Face not detected")
#    if b4 is not None:
#        arr4.append(b4)
#    else:
#        arr4.append("Face not detected")
#    if b5 is not None:
#        arr5.append(b5)
#    else:
#        arr5.append("Face  detected")
#    if b6 is not None:
#        arr6.append(b6)
#    else:
#        arr6.append("Face  detected")
#    if b7 is not None:
#        arr7.append(b7)
#    else:
#        arr7.append("Face  detected")
#    if b8 is not None:
#        arr8.append(b8)
#    else:
#        arr8.append("Face  detected")
# print(arr1)
# avg1 = np.mean(arr1)
# print(np.format_float_positional(avg1))
# print(arr2)   
# avg2 = np.mean(arr2)
# print(np.format_float_positional(avg2))
# print(arr3)
# avg3=np.mean(arr3)
# print(np.format_float_positional(avg3))
# avg4 = np.mean(arr4)
# print(arr4)
# print(np.format_float_positional(avg4))
# avg5=np.mean(arr5)
# print(arr5)
# print(np.format_float_positional(avg5))
# avg6=np.mean(arr6)
# print(arr6)
# print(np.format_float_positional(avg6))
# avg7=np.mean(arr7)
# print(arr7)
# print(np.format_float_positional(avg7))
# avg8=np.mean(arr8)
# print(arr8)
# print(np.format_float_positional(avg8))
# print("Processing complete. All images saved in:", output_folder)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 37
#      35 image = mp.Image(image_format=mp.ImageFormat.SRGB, data=frame_rgb)
#      36 # זיהוי נקודות פנים
# ---> 37 detection_result = detector.detect(image)
#      38 if detection_result.face_landmarks:
#      39     # ציור הנקודות ושמירת התוצאה
#      40     annotated_image = draw_landmarks_on_image(image.numpy_view(), detection_result)
#
# NameError: name 'detector' is not defined

# %%
arrFase=["1 Eyes close together","1 Eyes far apart","2 Self-confidence with facial width","2 Lack of self-confidence with the width of the face",
         "3 Judgment ability varies according to the position of the inner corners of the eyes","3 Judgment is fixed with the position of the inner corners of the eyes",
         "4","4","5 Small distance between the eye and the eyebrow","5 Large distance between the eye and the eyebrow","6 wide nostrils","6 narrow nostrils",
         "7 Lip tip slants downwards","7  Lip tip is tilted upwards","8 Large distance between nose and chin","8 Small distance between nose and chin"]

# %%
import time
a = 0b00001010
b = 0b00001011
start = time.perf_counter()
c = a | b
end = time.perf_counter()
print(f"c = {c}")
print(f"זמן ריצה: {end - start:.8f} שניות")
# Out:
# c = 11
# זמן ריצה: 0.00009650 שניות

# %%
# הערימה שלכאורה מיותרת
# import heapq
# class MaxHeap:
#     def __init__(self):
#         self.heap = []
#     def insert(self, val, name):
#         # נכניס tuple: הערך השלילי (למקסימום), והשם
#         heapq.heappush(self.heap, (-val, name))
#     def get_max(self):
#         if not self.heap:
#             return None
#         # שליפת המקסימום והסרה מהערימה
#         val, name = heapq.heappop(self.heap)
#         return (-val, name)
#     def get_heap(self): 
#         # נחזיר את כל הערכים במבנה חיובי + שמות
#         return [(-val, name) for val, name in self.heap]
# שימוש:
# max_heap = MaxHeap()
    # max_heap.insert(v, bin(int(personality_data[str(i)]["name"],2)))  # הוספת v והשם לערימה
# # שליפת 4 הערכים המקסימליים
# for i in range(0, 4):
#     max_value, max_name = max_heap.get_max()
#     print(f"Max value: {max_value}, Name: {max_name}")
#     a|=int(max_name,2)
